# %%
from Orderbook_Preprocessing import *

# %% [markdown]
# # Filter matched orders

# %%
countries = ['austria', 'germany']
years = [2022, 2023, 2024]

for country in countries:
    for year in years:
        print(f'{country}, {year}')
        filter_raw_data(country, year)

# %% [markdown]
# # Merge filtered orders

# %%
prepath = 'Data/' # path to the filered matched data from the previous step
countries = ['austria', 'germany']
resolutions = ['h', 'qh']

for country in countries:
    for resolution in resolutions:
        print(f'{country}, {resolution}')
        merge_filtered_data(resolution, country, prepath)
# Out:
# austria, h
# austria, qh
# germany, h
# germany, qh

# %% [markdown]
# # Extract features

# %%
countries = ['austria', 'germany']
resolutions = ['h', 'qh']
indices = ['ID1', 'ID2', 'ID3']
side = True

for country in countries:
    for resolution in resolutions:
        for indice in indices:
            print(f'{country}, {resolution}, {indice}')
            execute_feature_extraction(resolution, country, indice, side)
# Out:
# austria, h, ID1
# Processing groups: 100%|██████████| 26301/26301 [03:28<00:00, 126.34group/s, Processing date: 2024-12-31 22:00:00+00:00]
# Processing groups: 100%|██████████| 26298/26298 [03:39<00:00, 119.82group/s, Processing date: 2024-12-31 22:00:00+00:00]
# austria, h, ID2
# Processing groups: 100%|██████████| 26301/26301 [03:52<00:00, 113.19group/s, Processing date: 2024-12-31 22:00:00+00:00]
# Processing groups: 100%|██████████| 26298/26298 [03:57<00:00, 110.74group/s, Processing date: 2024-12-31 22:00:00+00:00]
# austria, h, ID3
# Processing groups: 100%|██████████| 26301/26301 [03:33<00:00, 123.29group/s, Processing date: 2024-12-31 22:00:00+00:00]
# Processing groups: 100%|██████████| 26298/26298 [03:16<00:00, 133.61group/s, Processing date: 2024-12-31 22:00:00+00:00]
# germany, h, ID1
# Processing groups: 100%|██████████| 26304/26304 [04:22<00:00, 100.23group/s, Processing date: 2024-12-31 22:00:00+00:00]
# Processing groups: 100%|██████████| 26304/26304 [04:06<00:00, 106.88group/s, Processing date: 2024-12-31 22:00:00+00:00]
# germany, h, ID2
# Processing groups: 100%|██████████| 26304/26304 [04:03<00:00, 108.08group/s, Processing date: 2024-12-31 22:00:00+00:00]
# Processing groups: 100%|██████████| 26304/26304 [03:59<00:00, 109.76group/s, Processing date: 2024-12-31 22:00:00+00:00]
# germany, h, ID3
# Processing groups: 100%|██████████| 26304/26304 [04:01<00:00, 108.81group/s, Processing date: 2024-12-31 22:00:00+00:00]
# Processing groups: 100%|██████████| 26304/26304 [03:54<00:00, 112.20group/s, Processing date: 2024-12-31 22:00:00+00:00]

# %%
countries = ['austria', 'germany']
resolutions = ['h']
indices = ['ID1', 'ID2', 'ID3']
side = False

for country in countries:
    for resolution in resolutions:
        for indice in indices:
            print(f'{country}, {resolution}, {indice}')
            execute_feature_extraction(resolution, country, indice, side)

# %% [markdown]
# # Extract labels

# %%
countries = ['austria', 'germany']
resolutions = ['h', 'qh']
indices = ['ID1', 'ID2', 'ID3']
side = False

for country in countries:
    for resolution in resolutions:
        for indice in indices:
            print(f'{country}, {resolution}, {indice}')
            execute_label_extraction(resolution, country, indice, side)
# Out:
# austria, h, ID1
# Extracting labels: 100%|██████████| 26301/26301 [00:08<00:00, 3250.88group/s]
# austria, h, ID2
# Extracting labels: 100%|██████████| 26301/26301 [00:08<00:00, 3104.99group/s]
# austria, h, ID3
# Extracting labels: 100%|██████████| 26301/26301 [00:08<00:00, 3090.38group/s]
# austria, qh, ID1
# Extracting labels: 100%|██████████| 105199/105199 [00:33<00:00, 3186.17group/s]
# austria, qh, ID2
# Extracting labels: 100%|██████████| 105199/105199 [00:33<00:00, 3146.98group/s]
# austria, qh, ID3
# Extracting labels: 100%|██████████| 105199/105199 [00:33<00:00, 3116.08group/s]
# germany, h, ID1
# Extracting labels: 100%|██████████| 26304/26304 [00:21<00:00, 1206.56group/s]
# germany, h, ID2
# Extracting labels: 100%|██████████| 26304/26304 [00:26<00:00, 995.75group/s]
# germany, h, ID3
# Extracting labels: 100%|██████████| 26304/26304 [00:28<00:00, 914.09group/s]
# germany, qh, ID1
# Extracting labels: 100%|██████████| 105216/105216 [04:03<00:00, 432.29group/s]
# germany, qh, ID2
# Extracting labels: 100%|██████████| 105216/105216 [03:50<00:00, 456.78group/s]
# germany, qh, ID3
# Extracting labels: 100%|██████████| 105216/105216 [03:44<00:00, 468.58group/s]

# %% [markdown]
# # Get price scaler

# %%
train_start_date = '2022-01-01'
train_end_date = '2024-01-01'

countries = ['austria', 'germany']
resolutions = ['h', 'qh']

for country in countries:
    for resolution in resolutions:
        fit_and_save_price_scaler(country, resolution, train_start_date, train_end_date)
